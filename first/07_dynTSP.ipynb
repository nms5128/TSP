# %%
import os
import time

import multiprocessing as mp

#locationPrefix = "/home/tfuser/programming"
#locationPrefix = "/mnt/c/Users/Zadran_Ghazohod/OneDrive"
locationPrefix = "/mnt/c/Users/tfUser/OneDrive"
homeLocation = os.getcwd()
libsLocation = os.path.join(locationPrefix, "gdrove", "tf")


os.chdir(libsLocation)
import tsp.tsp_proc as tsp
import all_aux as au
os.chdir(homeLocation)


print("Ok!")
# Out:
# Ok!

# %%
'''
MLPC, 13 towns, 14 procs: Ok! Total count: 239,500,800. Time taken: 106.48 sec.
MLPC, 14 towns, 14 procs: Ok! Total count: 3,113,510,400. Time taken: 1339.78 sec.
MLPC, 15 towns, 22 procs: Ok! Total count: 43,589,145,600. Time taken: 17702.65 sec.

HSCH, 13 towns, 10 procs: Ok! Total count: 239,500,800. Time taken: 149.67 sec.
HSCH, 13 towns, 14 procs: Ok! Total count: 239,500,800. Time taken: 121.86 sec.
HSCH, 14 towns, 14 procs: Ok! Total count: 3,113,510,400. Time taken: 1692.29 sec.

DLNB, 12 towns, 3 procs:  Ok! Total count: 19958400. Time taken: 67.81 sec.
DLNB, 13 towns, 3 procs:  Ok! Total count: 239500800. Time taken: 869.20 sec.
'''

## INPUTS
numTowns = 13
headSize = 2
numWorkers = 3

print("Ok!")
# Out:
# Ok!

# %%
'''

'''

idlessTowns = tsp.generateTowns(n=numTowns)
townIds = list(range(len(idlessTowns)))
xs = [t[1][0] for t in idlessTowns]
ys = [t[1][1] for t in idlessTowns]

towns = [(i,)+town for i,town in zip(townIds, idlessTowns)]
tsp.plotTowns(towns)

# %%
timeStart = time.time()

numRoutes = tsp.phuc(len(townIds)-1) // 2
print("HST: Expected usefull routes count: {}".format(numRoutes))

heads = tsp.headsFn(townIds, headSize=headSize)
heads = tsp.startEndShuffle(heads)
batches = tsp.batchList(heads, numBatches=numWorkers)

distMatrix = tsp.xyDistMatrix(xs, ys)

print("HST: creating workers")
quesToCnt = [mp.Queue() for _ in range(numWorkers)]
queToHost = mp.Queue()

workers = [mp.Process(target=tsp.cntWorkerFn(no, townIds, distMatrix, name="countFn_{}".format(no)),
                      args=(queToCnt, queToHost)) \
           for no,queToCnt in enumerate(quesToCnt)]

for worker in workers:
    worker.start()
    
for queToCnt,batch in zip(quesToCnt, batches):
    queToCnt.put(tsp.LoadMsg(load=batch))
    
numRunningWorkers = numWorkers
candidates = []
currentRoutesCount = 0
running = True
while running:
    msg = queToHost.get()
    
    if isinstance(msg, tsp.PoisonMsg):
        numRunningWorkers -= 1
        if numRunningWorkers < 1:
            running = False
            
    elif isinstance(msg, tsp.InfoMsg):
        info = msg.info
        if isinstance(info, dict):
            if info["summary"] == "Routes Count Report":
                currentRoutesCount += info["count"]
                print("HST: Current routes count: {} / {}".format(currentRoutesCount, numRoutes))
                
            elif info["summary"] == "Something Else":
                pass
            
            else:
                print("HST: Strange info message recieved")
        
        else:
            print(info)
        
    elif isinstance(msg, tsp.LoadMsg):
        candidates += [msg.load]
        
    else:
        print("HST: recieved a message of unknown purpose")
        
for queToCnt in quesToCnt:
    queToCnt.put(tsp.PoisonMsg())
    
for worker in workers:
    worker.join()
    
for que in quesToCnt:
    que.close()
        
minRoute = None
minDistance = 999.0
totalCount = 0
for c in candidates:
    if c[1] < minDistance:
        minRoute = c[0]
        minDistance = c[1]
    totalCount += c[2]
        
print("{} ==> {}".format(minRoute, minDistance))

timeTaken = time.time() - timeStart
print("Ok! Total count: {}. Time taken: {} sec.".format(totalCount, "%.2f"%timeTaken))
# Out:
# HST: Expected usefull routes count: 239500800
# HST: creating workers
# CNT0: starting...
# CNT1: starting...
# CNT2: starting...
# CNT0: heads recieved: (1, 2)...
# CNT1: heads recieved: (10, 2)...
# CNT2: heads recieved: (8, 4)...
# HST: Current routes count: 725760 / 239500800
# HST: Current routes count: 2177280 / 239500800
# HST: Current routes count: 5806080 / 239500800
# HST: Current routes count: 5806080 / 239500800
# HST: Current routes count: 8346240 / 239500800
# HST: Current routes count: 11612160 / 239500800
# HST: Current routes count: 12337920 / 239500800
# HST: Current routes count: 13789440 / 239500800
# HST: Current routes count: 17418240 / 239500800
# HST: Current routes count: 17781120 / 239500800
# HST: Current routes count: 20321280 / 239500800
# HST: Current routes count: 23587200 / 239500800
# HST: Current routes count: 24312960 / 239500800
# HST: Current routes count: 25764480 / 239500800
# HST: Current routes count: 29393280 / 239500800
# HST: Current routes count: 29756160 / 239500800
# HST: Current routes count: 33022080 / 239500800
# HST: Current routes count: 35562240 / 239500800
# HST: Current routes count: 36288000 / 239500800
# HST: Current routes count: 37739520 / 239500800
# HST: Current routes count: 41368320 / 239500800
# HST: Current routes count: 41731200 / 239500800
# HST: Current routes count: 44634240 / 239500800
# HST: Current routes count: 47174400 / 239500800
# HST: Current routes count: 47900160 / 239500800
# HST: Current routes count: 49351680 / 239500800
# HST: Current routes count: 52980480 / 239500800
# HST: Current routes count: 55883520 / 239500800
# HST: Current routes count: 56246400 / 239500800
# HST: Current routes count: 58786560 / 239500800
# HST: Current routes count: 59875200 / 239500800
# HST: Current routes count: 61326720 / 239500800
# HST: Current routes count: 64955520 / 239500800
# HST: Current routes count: 67858560 / 239500800
# HST: Current routes count: 68221440 / 239500800
# HST: Current routes count: 70761600 / 239500800
# HST: Current routes count: 71850240 / 239500800
# HST: Current routes count: 73301760 / 239500800
# HST: Current routes count: 76930560 / 239500800
# HST: Current routes count: 79833600 / 239500800
# HST: Current routes count: 80196480 / 239500800
# HST: Current routes count: 82736640 / 239500800
# HST: Current routes count: 83825280 / 239500800
# HST: Current routes count: 85276800 / 239500800
# HST: Current routes count: 88905600 / 239500800
# HST: Current routes count: 91808640 / 239500800
# HST: Current routes count: 92171520 / 239500800
# HST: Current routes count: 94348800 / 239500800
# HST: Current routes count: 95437440 / 239500800
# HST: Current routes count: 96888960 / 239500800
# HST: Current routes count: 100517760 / 239500800
# HST: Current routes count: 102695040 / 239500800
# HST: Current routes count: 105598080 / 239500800
# HST: Current routes count: 105960960 / 239500800
# HST: Current routes count: 107049600 / 239500800
# HST: Current routes count: 108864000 / 239500800
# HST: Current routes count: 112492800 / 239500800
# HST: Current routes count: 114670080 / 239500800
# HST: Current routes count: 117573120 / 239500800
# HST: Current routes count: 117936000 / 239500800
# HST: Current routes count: 119024640 / 239500800
# HST: Current routes count: 120839040 / 239500800
# HST: Current routes count: 124467840 / 239500800
# HST: Current routes count: 127370880 / 239500800
# HST: Current routes count: 127733760 / 239500800
# HST: Current routes count: 129911040 / 239500800
# HST: Current routes count: 130999680 / 239500800
# HST: Current routes count: 132814080 / 239500800
# HST: Current routes count: 136442880 / 239500800
# HST: Current routes count: 136805760 / 239500800
# HST: Current routes count: 139708800 / 239500800
# HST: Current routes count: 141886080 / 239500800
# HST: Current routes count: 142974720 / 239500800
# HST: Current routes count: 144789120 / 239500800
# HST: Current routes count: 148055040 / 239500800
# HST: Current routes count: 148417920 / 239500800
# HST: Current routes count: 151320960 / 239500800
# HST: Current routes count: 153498240 / 239500800
# HST: Current routes count: 154586880 / 239500800
# HST: Current routes count: 156401280 / 239500800
# HST: Current routes count: 159667200 / 239500800
# HST: Current routes count: 160392960 / 239500800
# HST: Current routes count: 163296000 / 239500800
# HST: Current routes count: 165473280 / 239500800
# HST: Current routes count: 166561920 / 239500800
# HST: Current routes count: 168376320 / 239500800
# HST: Current routes count: 171642240 / 239500800
# HST: Current routes count: 172368000 / 239500800
# HST: Current routes count: 175271040 / 239500800
# HST: Current routes count: 177448320 / 239500800
# HST: Current routes count: 178536960 / 239500800
# HST: Current routes count: 180351360 / 239500800
# HST: Current routes count: 183617280 / 239500800
# HST: Current routes count: 184343040 / 239500800
# HST: Current routes count: 186883200 / 239500800
# HST: Current routes count: 189060480 / 239500800
# HST: Current routes count: 190149120 / 239500800
# HST: Current routes count: 191963520 / 239500800
# HST: Current routes count: 195229440 / 239500800
# HST: Current routes count: 197769600 / 239500800
# HST: Current routes count: 198495360 / 239500800
# HST: Current routes count: 200672640 / 239500800
# HST: Current routes count: 202124160 / 239500800
# HST: Current routes count: 203938560 / 239500800
# HST: Current routes count: 207204480 / 239500800
# HST: Current routes count: 209744640 / 239500800
# HST: Current routes count: 210470400 / 239500800
# HST: Current routes count: 212647680 / 239500800
# HST: Current routes count: 214099200 / 239500800
# HST: Current routes count: 215913600 / 239500800
# HST: Current routes count: 219179520 / 239500800
# HST: Current routes count: 221719680 / 239500800
# HST: Current routes count: 222445440 / 239500800
# HST: Current routes count: 224622720 / 239500800
# HST: Current routes count: 226074240 / 239500800
# HST: Current routes count: 227888640 / 239500800
# HST: Current routes count: 231154560 / 239500800
# HST: Current routes count: 233694720 / 239500800
# CNT1: candidate sent. Shutting down...
# HST: Current routes count: 234420480 / 239500800
# HST: Current routes count: 236234880 / 239500800
# CNT2: candidate sent. Shutting down...
# HST: Current routes count: 239500800 / 239500800
# CNT0: candidate sent. Shutting down...
# (0, 6, 5, 8, 10, 11, 2, 4, 7, 12, 3, 1, 9, 0) ==> 7.273659963815775
# Ok! Total count: 239500800. Time taken: 869.20 sec.

# %%
targetRoute = [  [t for t in towns if t[0]==ms][0]  for ms in minRoute  ]
tsp.plotTowns(towns, shortestTravel=targetRoute, plotSize=10)
